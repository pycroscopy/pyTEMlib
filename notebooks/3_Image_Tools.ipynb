# %% [markdown]
# <font size = "5"> **[pyTEMlib](0_pyTEMlib.ipynb)** </font>
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
#
# # Image Tools
#
#
# part of
#
# <font size = "4"> **pyTEMlib**, a **pycroscopy** library </font>
#
#
# Notebook by
#
# Gerd Duscher
#
# Materials Science & Engineering<br>
# Joint Institute of Advanced Materials<br>
# The University of Tennessee, Knoxville
#
#
# Usage of the Image Tools of [pyTEMlib](_pyTEMlib.ipynb)
#
# ## [Adaptive_Fourier_Filter](./Imaging/I1_Adaptive_Fourier_Filter.ipynb)
# ## [Register Image Stack](./Imaging/I2_Register_Image_Stack.ipynb)
# ## [Electron Probe](./Imaging/I3_Probe.ipynb)
# ## [Structure Analysis](I4_Structure_Analysis.ipynb)
