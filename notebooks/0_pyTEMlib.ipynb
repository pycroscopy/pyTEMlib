# %% [markdown]
# <font size = "5"> **[pyTEMlib](0_pyTEMlib.ipynb)** </font>
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
#
# <font size = "5"> **[pyTEMlib](0_pyTEMlib.ipynb)**, a **pycroscopy** library </font>
#
#
# Notebook by
#
# Gerd Duscher
#
# Materials Science & Engineering<br>
# Joint Institute of Advanced Materials<br>
# The University of Tennessee, Knoxville
#
#
# Usage of the  Tools of [pyTEMlib](_pyTEMlib.ipynb)
#
# PyTEMlib enables model-based analysis of microscopy data.
#
# That means that we fit a function to the data and the fitting parameter have a quantitative and physical meaning.
#
# This package is divided in 4 major parts:
#
# # [Introduction](1_Introduction.ipynb)
# # [Diffraction Tools](2.ipynb)
# # [Image Tools](3_Image_Tools.ipynb)
# # [Spectroscopy_Tools](4_Spectroscopy_Tools.ipynb)
