# %% [markdown]
# <font size = "5"> **Chapter 4:  [Spectroscopy](Ch4-Spectroscopy.ipynb)** </font>
#
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
# # Analysis of Core-Loss Spectra
#
# part of
#
# <font size = "5"> **[Analysis of Transmission Electron Microscope Data](_Analysis_of_Transmission_Electron_Microscope_Data.ipynb)**</font>
#
#
# by Gerd Duscher, 2020
#
# Microscopy Facilities<br>
# Joint Institute of Advanced Materials<br>
# The University of Tennessee, Knoxville
#
# Model based analysis and quantification of data acquired with transmission electron microscopes
#
#
# ## Install the newest version of sidpy
# This notebook will only run with  ``version 0.0.3`` or higher.

# %%
import sys
from IPython.lib.deepreload import reload as dreload

try:
    import sidpy 
except ModuleNotFoundError:
    # !pip3 install sidpy
if sidpy.__version__ < '0.0.3':
    # !{sys.executable} -m pip install  --upgrade sidpy
    dreload(sidpy)
try:
    import pyNSID 
except ModuleNotFoundError:
    # !{sys.executable} -m pip install  --upgrade pyNSID
try:
    import pyTEMlib
except ModuleNotFoundError:
    # !{sys.executable} -m pip install  --upgrade pyTEMlib
if pyTEMlib.__version__ < '0.2020.11.0':
    # !{sys.executable} -m pip install  --upgrade pyTEMlib
    dreload(pyTEMlib)
# Out:
# Collecting pyTEMlib
#   Downloading pyTEMlib-0.2020.11.0-py3-none-any.whl (483 kB)
# Requirement already satisfied, skipping upgrade: simpleITK in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (2.0.1)
# Requirement already satisfied, skipping upgrade: pillow in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (8.0.1)
# Requirement already satisfied, skipping upgrade: ase in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (3.19.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (1.19.2)
# Requirement already satisfied, skipping upgrade: pyNSID in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (0.0.1)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\gduscher\anaconda3\lib\site-packages (from pyTEMlib) (1.5.0)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\gduscher\anaconda3\lib\site-packages (from ase->pyTEMlib) (3.3.2)
# Requirement already satisfied, skipping upgrade: cytoolz in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (0.11.0)
# Requirement already satisfied, skipping upgrade: ipywidgets>=5.2.2 in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (7.5.1)
# Requirement already satisfied, skipping upgrade: dask>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (2.30.0)
# Requirement already satisfied, skipping upgrade: sidpy>=0.0.2 in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (0.0.3)
# Requirement already satisfied, skipping upgrade: ipython>=6.0; python_version >= "3.3" in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (7.18.1)
# Requirement already satisfied, skipping upgrade: h5py>=2.6.0 in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (2.10.0)
# Requirement already satisfied, skipping upgrade: six in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (1.15.0)
# Requirement already satisfied, skipping upgrade: toolz in c:\users\gduscher\anaconda3\lib\site-packages (from pyNSID->pyTEMlib) (0.11.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib->ase->pyTEMlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib->ase->pyTEMlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib->ase->pyTEMlib) (2020.6.20)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib->ase->pyTEMlib) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\gduscher\anaconda3\lib\site-packages (from matplotlib->ase->pyTEMlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyNSID->pyTEMlib) (3.5.1)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyNSID->pyTEMlib) (5.3.4)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyNSID->pyTEMlib) (5.0.8)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\gduscher\anaconda3\lib\site-packages (from ipywidgets>=5.2.2->pyNSID->pyTEMlib) (5.0.5)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\gduscher\anaconda3\lib\site-packages (from dask>=0.10->pyNSID->pyTEMlib) (5.3.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11.0 in c:\users\gduscher\anaconda3\lib\site-packages (from sidpy>=0.0.2->pyNSID->pyTEMlib) (0.17.0)
# Requirement already satisfied, skipping upgrade: psutil in c:\users\gduscher\anaconda3\lib\site-packages (from sidpy>=0.0.2->pyNSID->pyTEMlib) (5.7.3)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.7.5)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (3.0.8)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.2.0)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.4.4)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (4.4.2)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (49.6.0.post20201009)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.17.1)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\gduscher\anaconda3\lib\site-packages (from ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (2.7.2)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\gduscher\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (6.1.4)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\gduscher\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (6.1.7)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\gduscher\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (6.0.4)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.2.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (3.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\gduscher\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (4.6.3)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\gduscher\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.2.5)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\gduscher\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=6.0; python_version >= "3.3"->pyNSID->pyTEMlib) (0.7.0)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (6.0.7)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.8.0)
# Requirement already satisfied, skipping upgrade: argon2-cffi in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (20.1.0)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.5.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (19.0.2)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (2.11.2)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.3 in c:\users\gduscher\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.9.1)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\gduscher\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.17.3)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\gduscher\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (20.2.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\gduscher\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (228)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.4.2)
# Requirement already satisfied, skipping upgrade: nbclient<0.6.0,>=0.5.0 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.5.1)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (3.2.1)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.8.4)
# Requirement already satisfied, skipping upgrade: jupyterlab-pygments in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.1.2)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.4.4)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.6.0)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\gduscher\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.3)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\gduscher\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.14.3)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\gduscher\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.1.1)
# Requirement already satisfied, skipping upgrade: pywinpty>=0.5; os_name == "nt" in c:\users\gduscher\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.5.7)
# Requirement already satisfied, skipping upgrade: async-generator in c:\users\gduscher\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.10)
# Requirement already satisfied, skipping upgrade: nest-asyncio in c:\users\gduscher\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (1.4.1)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\gduscher\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (20.4)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\gduscher\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (0.5.1)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\gduscher\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.2.2->pyNSID->pyTEMlib) (2.20)
# Installing collected packages: pyTEMlib
#   Attempting uninstall: pyTEMlib
#     Found existing installation: pyTEMlib 0.2020.10.3
#     Uninstalling pyTEMlib-0.2020.10.3:
#       Successfully uninstalled pyTEMlib-0.2020.10.3
# Successfully installed pyTEMlib-0.2020.11.0
# ReloadingReloading  zmq
# _io
# Reloading _io
# Reloading sys
# Reloading platform
# Reloading collections
# Reloading _collections_abc
# Reloading abc
# Reloading _abc
# Reloading operator
# Reloading builtins

# %% [markdown]
# ## Content
#
# Quantitative determination of chemical composition from a core-loss EELS spectrum
#
# Please cite:
#
# [M. Tian et  al. *Measuring the areal density of nanomaterials by electron energy-loss spectroscopy*
# Ultramicroscopy Volume 196, 2019, pages 154-160](https://doi.org/10.1016/j.ultramic.2018.10.009)
#
# as a reference of this quantification method.

# %% [markdown]
# ## First we import the relevant packages

# %%
# %pylab --no-import-all notebook
# %gui qt

import pyTEMlib
import pyTEMlib.file_tools as ft
import pyTEMlib.image_tools as it
import pyTEMlib.eels_tools  as eels        # EELS methods 
import pyTEMlib.interactive_eels as ieels  # Dialogs for EELS input and quantification

# For archiving reasons it is a good idea to print the version numbers out at this point
print('pyTEM version: ',pyTEMlib.__version__)

__notebook__ = 'analyse_core_loss'
__notebook_version__ = '2020_11_03'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# advanced EELS features enabled
# pyTEM version:  0.2020.11.0

# %% [markdown]
# %load_ext autoreload
# %autoreload 2
#
# import sys
# sys.path.insert(0,'../pyTEMlib/')

# %% [markdown]
# ## Load and plot a spectrum
#
# As an example we load the spectrum **1EELS Acquire (high-loss).dm3** from the *example data* folder.
#
# Please see [Loading an EELS Spectrum](LoadEELS.ipynb) for details on storage and plotting.
#
# First a dialog to select a file will apear.
#
# Then the spectrum plot and ``Spectrum Info`` dialog will appear, in which we set the experimental parameters.
#
# Please use the ``Set Energy Scale`` button to change the energy scale. When pressed a new dialog and a cursor will appear in which one is able to set the energy scale based on known features in the spectrum.

# %%
try:
    current_dataset.h5_dataset.file.close()
except:
    pass
Qt_app = ft.get_qt_app()
current_dataset = ft.open_file()

current_channel = current_dataset.h5_dataset.parent

eels.set_previous_quantification(current_dataset)

# US 200 does not set acceleration voltage correctly.
# comment out next line  for other microscopes
current_dataset.metadata['experiment']['acceleration_voltage'] = 200000

info = ieels.InfoDialog(current_dataset)
# Out:
# Cannot overwrite file. Using:  10-EELS Acquire (dark ref corrected)CLDAl-51.hf5
# <HDF5 group "/Measurement_000/Channel_000" (0 members)> 10_EELS Acquire (dark ref corrected)CLDAl
# <img src="data:image/png;base64,..." width="960">

# %% [markdown]
# ## Chemical Composition
# The fit of the cross-section and background to the spectrum results in the chemical composition. If the calibration is correct this composition is given as areal density in atoms/nm$^2$
#
#
# ###  Fit of Data
# A dialog window will open, enter the elements first (0 will open a periodic table) and press
# ``Fit Composition`` button (bottom right). Adjust parameters as needed and check fit by pressing the ``Fit Composition`` button again.
#
# Select the ``Region`` checkbox to see which parts of the spectrum you choose to fit.
#
# Changing the multiplier value will make a simulation of your spectrum.
#
# The ``InfoDialog``, if open, still works to change experimental parameters and the energy scale.

# %%
# current_dataset.metadata['edges'] = {'0': {}, 'model': {}}
composition = ieels.CompositionDialog(current_dataset)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Output of Results

# %%
edges = current_dataset.metadata['edges']
element = []
areal_density = []
for key, edge in edges.items():
    if key.isdigit():
        element.append(edge['element'])
        areal_density.append(edge['areal_density'])

print('Relative chemical composition of ', current_dataset.title)
for i in range(len(element)):
    print(f'{element[i]}: {areal_density[i]/np.sum(areal_density)*100:.1f} %')
    
saved_edges_metadata = edges
# Out:
# Relative chemical composition of  10_EELS Acquire (dark ref corrected)CLDAl
# Ni: 3.7 %
# Ce: 3.4 %
# Al: 92.9 %

# %% [markdown]
# ### Log Data
# We write all the data to the hdf5 file associated with our dataset.
#
# In our case that is only the ``metadata``, in which we stored the ``experimental parameters`` and the ``fitting parameters and result``.

# %%
current_group = current_dataset.h5_dataset.parent
if 'Log_000' not in current_group:
    log_group = current_group.create_group('Log_000')
    
log_group = current_group['Log_000']
if 'analysis' in log_group:
    del log_group['analysis'] 
log_group['analysis'] = 'EELS_quantification'
metadata = ft.flatten_dict(current_dataset.metadata)
for key, item in metadata.items():
    log_group.attrs[key]= item
current_group.file.flush()

# %%
ft.h5_tree(current_group.file)
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ 10_EELS Acquire (dark ref corrected)CLDAl
#     ├ Log_000
#       -------
#       ├ analysis
#     ├ energy_loss
#     ├ metadata
#       --------
#     ├ original_metadata
#       -----------------

# %% [markdown]
# ## ELNES
# The electron energy-loss near edge structure is determined by fititng the spectrum after quantification model subtraction.
#
# First smooth the spectrum (2 iterations are ususally sufficient) and then
# find the number of peaks you want (Can be repeated as oftern as one wants).

# %%
peak_dialog = ieels.PeakFitDialog(current_dataset)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Output

# %%
areas = []
for p, peak in peak_dialog.peaks['peaks'].items():
    area = np.sqrt(2* np.pi)* peak['amplitude'] * np.abs(peak['width'] / np.sqrt(2 *np.log(2))) 
    areas.append(area)
    if 'associated_edge' not in peak:
        peak['associated_edge']= ''
    print(f"peak  {p}: position: {peak['position']:7.1f}, area: {area:12.3f} associated edge: {peak['associated_edge']}")
#print(f'\n M4/M5 peak 2 to peak 1 ratio: {(areas[1])/areas[0]:.2f}')
# Out:
# peak  0: position:   887.5, area:  1107730.507 associated edge: Ce-M5
# peak  1: position:   905.5, area:  1316919.645 associated edge: Ce-M4
# peak  2: position:  1096.3, area:    39423.290 associated edge:
# peak  3: position:   911.0, area:   137077.260 associated edge: Ce-M4
# peak  4: position:   898.2, area:  -134735.255 associated edge: Ce-M4
# peak  5: position:   859.9, area:    78637.129 associated edge:
# peak  6: position:  1183.4, area:    89611.358 associated edge: Ce-M3
# peak  7: position:   940.2, area:   -62371.861 associated edge: Ce-M4
# peak  8: position:  1571.8, area:    59819.156 associated edge: Al-K1
# peak  9: position:  1565.0, area:    32618.778 associated edge: Al-K1

# %% [markdown]
# ### Log Data

# %%
current_group = current_dataset.h5_dataset.parent
if 'Log_001' not in current_group:
    log_group = current_group.create_group('Log_001')
    
log_group = current_group['Log_001']
if 'analysis' in log_group:
    del log_group['analysis'] 
log_group['analysis'] = 'ELNES_fit'
metadata = ft.flatten_dict(current_dataset.metadata)
for key, item in metadata.items():
    log_group.attrs[key]= item
current_group.file.flush()

print('Logged Data of ', current_dataset.title)
for key in current_group:
    if 'Log_' in key:
        if 'analysis' in current_group[key]:
            print(f" {key}: {current_group[key]['analysis'][()]}")
# Out:
# Logged Data of  01_EELS Acquire_STO
#  Log_000: EELS_quantification
#  Log_001: ELNES_fit

# %% [markdown]
# ## Close File
# File needs to be closed to be used with other notebooks

# %%
current_dataset.h5_dataset.file.close()

# %% [markdown]
# ## Navigation
# <font size = "5"> **Back: [Calculating Dielectric Function II: Silicon](DielectricDFT2.ipynb)** </font>
#
# <font size = "5"> **Next: [ELNES](ELNES.ipynb)** </font>
#
# <font size = "5"> **Chapter 4: [Spectroscopy](Spectroscopy.ipynb)** </font>
#
# <font size = "5"> **Index: [Index](Analysis_of_Transmission_Electron_Microscope_Data.ipynb)** </font>
